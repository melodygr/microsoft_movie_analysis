# %% [markdown]
# # How have box office returns been changing over time?

# %%
# Also which movie ratings produce the highest box office revenue?

# %% [markdown]
# ## Data Cleaning opus_movie_data_df

# %%
import pandas as pd
import numpy as np
import requests

# %%
opus_movie_data_df = pd.read_csv('OpusMovieData.csv')
print(len(opus_movie_data_df))
opus_movie_data_df.head()
# Production year between 2006 and 2018.
# Figures for domestic or international box office.
# Production budget greater or equal to $10 million
# Out:
# 1936
#                  movie_name  production_year  movie_odid  production_budget  \
# 0    Madea's Family Reunion             2006     8220100           10000000
# 1                    Krrish             2006    58540100           10000000
# 2          End of the Spear             2006    34620100           10000000
# 3  A Prairie Home Companion             2006    24910100           10000000
# 4                   Saw III             2006     5840100           10000000
#
#    domestic_box_office  international_box_office     rating  \
# 0             63257940                     62581      PG-13
# 1              1430721                  31000000  Not Rated
# 2             11748661                    175380      PG-13
# 3             20342852                   6373339      PG-13
# 4             80238724                  83638091          R
#
#           creative_type               source production_method   genre  \
# 0  Contemporary Fiction        Based on Play       Live Action  Comedy
# 1       Science Fiction  Original Screenplay       Live Action  Action
# 2    Historical Fiction  Original Screenplay       Live Action   Drama
# 3  Contemporary Fiction  Original Screenplay       Live Action  Comedy
# 4  Contemporary Fiction  Original Screenplay       Live Action  Horror
#
#    sequel  running_time
# 0     1.0           NaN
# 1     1.0           NaN
# 2     0.0           NaN
# 3     0.0         105.0
# 4     1.0           NaN

# %%
# Check for duplicates - None
opus_movie_data_df.duplicated('movie_odid').sum()
# Out:
# 0

# %%
# Checking for columns with null values
opus_movie_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1936 entries, 0 to 1935
# Data columns (total 13 columns):
# movie_name                  1936 non-null object
# production_year             1936 non-null int64
# movie_odid                  1936 non-null int64
# production_budget           1936 non-null int64
# domestic_box_office         1936 non-null int64
# international_box_office    1936 non-null int64
# rating                      1913 non-null object
# creative_type               1923 non-null object
# source                      1915 non-null object
# production_method           1925 non-null object
# genre                       1926 non-null object
# sequel                      1934 non-null float64
# running_time                1822 non-null float64
# dtypes: float64(2), int64(5), object(6)
# memory usage: 196.8+ KB

# %%
# Apparently there are 23 null values in ratings. Set them to unknown.
opus_movie_data_df['rating'].value_counts()
# Out:
# PG-13        777
# R            748
# PG           311
# Not Rated     40
# G             36
# NC-17          1
# Name: rating, dtype: int64

# %%
opus_movie_data_df.rating.fillna('Unknown', inplace=True)
opus_movie_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1936 entries, 0 to 1935
# Data columns (total 13 columns):
# movie_name                  1936 non-null object
# production_year             1936 non-null int64
# movie_odid                  1936 non-null int64
# production_budget           1936 non-null int64
# domestic_box_office         1936 non-null int64
# international_box_office    1936 non-null int64
# rating                      1936 non-null object
# creative_type               1923 non-null object
# source                      1915 non-null object
# production_method           1925 non-null object
# genre                       1926 non-null object
# sequel                      1934 non-null float64
# running_time                1822 non-null float64
# dtypes: float64(2), int64(5), object(6)
# memory usage: 196.8+ KB

# %%
# Although I am not planning on using creative_type, source, production method or genre, lets replace those nulls too.

opus_movie_data_df.creative_type.fillna('Unknown', inplace=True)
opus_movie_data_df.source.fillna('Unknown', inplace=True)
opus_movie_data_df.production_method.fillna('Unknown', inplace=True)
opus_movie_data_df.genre.fillna('Unknown', inplace=True)
opus_movie_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1936 entries, 0 to 1935
# Data columns (total 13 columns):
# movie_name                  1936 non-null object
# production_year             1936 non-null int64
# movie_odid                  1936 non-null int64
# production_budget           1936 non-null int64
# domestic_box_office         1936 non-null int64
# international_box_office    1936 non-null int64
# rating                      1936 non-null object
# creative_type               1936 non-null object
# source                      1936 non-null object
# production_method           1936 non-null object
# genre                       1936 non-null object
# sequel                      1934 non-null float64
# running_time                1822 non-null float64
# dtypes: float64(2), int64(5), object(6)
# memory usage: 196.8+ KB

# %%
# Two records don't have a value for sequel.  I think it is safe to set them to 0 like most of the other movies
print(opus_movie_data_df.sequel.value_counts())
opus_movie_data_df[opus_movie_data_df.sequel.isna()]
# Out:
# 0.0    1639
# 1.0     295
# Name: sequel, dtype: int64
#                      movie_name  production_year  movie_odid  \
# 1898         PMC: deo beong-keo             2018   390770100
# 1918  The Kid Who Would Be King             2018   288100100
#
#       production_budget  domestic_box_office  international_box_office  \
# 1898           10300000                    0                  12478635
# 1918           59000000             16674053                   9400000
#
#        rating         creative_type               source production_method  \
# 1898  Unknown  Contemporary Fiction  Original Screenplay       Live Action
# 1918       PG               Fantasy  Original Screenplay       Live Action
#
#           genre  sequel  running_time
# 1898     Action     NaN         119.0
# 1918  Adventure     NaN         132.0

# %%
opus_movie_data_df.sequel.fillna(0.0, inplace=True)
opus_movie_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1936 entries, 0 to 1935
# Data columns (total 13 columns):
# movie_name                  1936 non-null object
# production_year             1936 non-null int64
# movie_odid                  1936 non-null int64
# production_budget           1936 non-null int64
# domestic_box_office         1936 non-null int64
# international_box_office    1936 non-null int64
# rating                      1936 non-null object
# creative_type               1936 non-null object
# source                      1936 non-null object
# production_method           1936 non-null object
# genre                       1936 non-null object
# sequel                      1936 non-null float64
# running_time                1822 non-null float64
# dtypes: float64(2), int64(5), object(6)
# memory usage: 196.8+ KB

# %%
# 114 records without a running time.  I don't plan to use it so I will leave it rather than put in an arbitrary value.
print(opus_movie_data_df.running_time.value_counts())
opus_movie_data_df[opus_movie_data_df.running_time.isna()]
# Out:
# 110.0    67
# 100.0    64
# 105.0    61
# 91.0     52
# 97.0     48
#          ..
# 69.0      1
# 191.0     1
# 169.0     1
# 172.0     1
# 159.0     1
# Name: running_time, Length: 95, dtype: int64
#                                  movie_name  production_year  movie_odid  \
# 0                    Madea's Family Reunion             2006     8220100
# 1                                    Krrish             2006    58540100
# 2                          End of the Spear             2006    34620100
# 4                                   Saw III             2006     5840100
# 6                                    Edmond             2006    78520100
# ..                                      ...              ...         ...
# 640                               Outlander             2009    76700100
# 663                                   Agora             2009   132890100
# 721                    The Killer Inside Me             2010   138570100
# 781  Sammy's avonturen: De geheime doorgang             2010   139890100
# 849        Arthur and the War of Two Worlds             2010   122310100
#
#      production_budget  domestic_box_office  international_box_office  \
# 0             10000000             63257940                     62581
# 1             10000000              1430721                  31000000
# 2             10000000             11748661                    175380
# 4             10000000             80238724                  83638091
# 6             10000000               131719                    110000
# ..                 ...                  ...                       ...
# 640           50000000               166003                   1084614
# 663           70000000               619423                  38372869
# 721           13000000               217277                   3400000
# 781           25000000                    0                  71594792
# 849           45500000               347136                  35833688
#
#         rating         creative_type                             source  \
# 0        PG-13  Contemporary Fiction                      Based on Play
# 1    Not Rated       Science Fiction                Original Screenplay
# 2        PG-13    Historical Fiction                Original Screenplay
# 4            R  Contemporary Fiction                Original Screenplay
# 6            R  Contemporary Fiction                      Based on Play
# ..         ...                   ...                                ...
# 640          R       Science Fiction                Original Screenplay
# 663          R    Historical Fiction                Original Screenplay
# 721          R               Unknown                            Unknown
# 781         PG          Kids Fiction                Original Screenplay
# 849         PG               Fantasy  Based on Fiction Book/Short Story
#
#          production_method         genre  sequel  running_time
# 0              Live Action        Comedy     1.0           NaN
# 1              Live Action        Action     1.0           NaN
# 2              Live Action         Drama     0.0           NaN
# 4              Live Action        Horror     1.0           NaN
# 6              Live Action  Black Comedy     0.0           NaN
# ..                     ...           ...     ...           ...
# 640            Live Action     Adventure     0.0           NaN
# 663            Live Action         Drama     0.0           NaN
# 721            Live Action         Drama     0.0           NaN
# 781      Digital Animation     Adventure     0.0           NaN
# 849  Animation/Live Action     Adventure     0.0           NaN
#
# [114 rows x 13 columns]

# %%
# create feature of world_wide_box_office
opus_movie_data_df['world_wide_box_office'] = opus_movie_data_df['domestic_box_office'] + opus_movie_data_df['international_box_office']
opus_movie_data_df.head()
# Out:
#                  movie_name  production_year  movie_odid  production_budget  \
# 0    Madea's Family Reunion             2006     8220100           10000000
# 1                    Krrish             2006    58540100           10000000
# 2          End of the Spear             2006    34620100           10000000
# 3  A Prairie Home Companion             2006    24910100           10000000
# 4                   Saw III             2006     5840100           10000000
#
#    domestic_box_office  international_box_office     rating  \
# 0             63257940                     62581      PG-13
# 1              1430721                  31000000  Not Rated
# 2             11748661                    175380      PG-13
# 3             20342852                   6373339      PG-13
# 4             80238724                  83638091          R
#
#           creative_type               source production_method   genre  \
# 0  Contemporary Fiction        Based on Play       Live Action  Comedy
# 1       Science Fiction  Original Screenplay       Live Action  Action
# 2    Historical Fiction  Original Screenplay       Live Action   Drama
# 3  Contemporary Fiction  Original Screenplay       Live Action  Comedy
# 4  Contemporary Fiction  Original Screenplay       Live Action  Horror
#
#    sequel  running_time  world_wide_box_office
# 0     1.0           NaN               63320521
# 1     1.0           NaN               32430721
# 2     0.0           NaN               11924041
# 3     0.0         105.0               26716191
# 4     1.0           NaN              163876815

# %% [markdown]
# **Data cleaning details:**
#
# * Checked for duplicates.
# * Set 23 null values in ratings to unknown.
# * Set 13 null values in creative_type to unknown.
# * Set 21 null values in source to unknown.
# * Set 11 null values in production_method to unknown.
# * Set 10 null values in genre to unknown.
# * Set 2 null values in sequel to 0.0
# * Add column for world wide box office value equal to domestic plus international.

# %%
# I think the data is clean now and ready for some analysis.  Let's save it to a .csv file and then read it back in.

opus_movie_data_df.to_csv('cleanedData/clean_opus_movie_data_df.csv')

clean_opus_movie_data_df = pd.read_csv('cleanedData/clean_opus_movie_data_df.csv',index_col=[0])
print(len(clean_opus_movie_data_df))
clean_opus_movie_data_df.head()
# Out:
# 1936
#                  movie_name  production_year  movie_odid  production_budget  \
# 0    Madea's Family Reunion             2006     8220100           10000000
# 1                    Krrish             2006    58540100           10000000
# 2          End of the Spear             2006    34620100           10000000
# 3  A Prairie Home Companion             2006    24910100           10000000
# 4                   Saw III             2006     5840100           10000000
#
#    domestic_box_office  international_box_office     rating  \
# 0             63257940                     62581      PG-13
# 1              1430721                  31000000  Not Rated
# 2             11748661                    175380      PG-13
# 3             20342852                   6373339      PG-13
# 4             80238724                  83638091          R
#
#           creative_type               source production_method   genre  \
# 0  Contemporary Fiction        Based on Play       Live Action  Comedy
# 1       Science Fiction  Original Screenplay       Live Action  Action
# 2    Historical Fiction  Original Screenplay       Live Action   Drama
# 3  Contemporary Fiction  Original Screenplay       Live Action  Comedy
# 4  Contemporary Fiction  Original Screenplay       Live Action  Horror
#
#    sequel  running_time  world_wide_box_office
# 0     1.0           NaN               63320521
# 1     1.0           NaN               32430721
# 2     0.0           NaN               11924041
# 3     0.0         105.0               26716191
# 4     1.0           NaN              163876815

# %% [markdown]
# ## Data Analysis and Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
